# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Data Covid19.csv")
data.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  Recovered
# 0          Hubei  Mainland China  1/22/2020 17:00        444      17         28
# 1          Hubei  Mainland China    1/23/20 17:00        444      17         28
# 2          Hubei  Mainland China    1/23/20 17:00        444      17         28
# 3          Hubei  Mainland China    1/24/20 17:00        549      24         31
# 4          Hubei  Mainland China    1/25/20 17:00        761      40         32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114358 entries, 0 to 114357
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  114358 non-null  object
#  1   Country/Region  114358 non-null  object
#  2   Last Update     114358 non-null  object
#  3   Confirmed       114358 non-null  int64
#  4   Deaths          114358 non-null  int64
#  5   Recovered       114358 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 5.2+ MB

# %%
data['Last Update'].unique()
# Out:
# array(['1/22/2020 17:00', '1/23/20 17:00', '1/24/20 17:00', ...,
#        '26/02/2021 05.22', '27/02/2021 05.22', '28/02/2021 05.22'],
#       dtype=object)

# %%
latest_date = '28/02/2021 05.22'
data[data['Last Update']==latest_date]
# Out:
#             Province/State  Country/Region  ... Deaths  Recovered
# 113959             Abruzzo           Italy  ...   1698      39479
# 113960                Acre          Brazil  ...    996      46623
# 113961     Adygea Republic          Russia  ...    149      12159
# 113962               Aichi           Japan  ...    515      24524
# 113963               Akita           Japan  ...      6        260
# ...                    ...             ...  ...    ...        ...
# 114353    Zabaykalsky Krai          Russia  ...    528      36849
# 114354  Zakarpattia Oblast         Ukraine  ...    900      30516
# 114355   Zaporizhia Oblast         Ukraine  ...   1132      65049
# 114356            Zhejiang  Mainland China  ...      1       1314
# 114357     Zhytomyr Oblast         Ukraine  ...    834      44309
#
# [399 rows x 6 columns]

# %%
unique_countries = data[data.Confirmed>0]['Country/Region'].unique()
unique_countries.sort()
unique_countries
# Out:
# array(['Australia', 'Brazil', 'Canada', 'Chile', 'Colombia', 'Denmark',
#        'France', 'Germany', 'Hong Kong', 'India', 'Italy', 'Japan',
#        'Mainland China', 'Mexico', 'Netherlands', 'Others', 'Pakistan',
#        'Peru', 'Russia', 'Spain', 'Taiwan', 'UK', 'US', 'Ukraine'],
#       dtype=object)

# %%
country_confirmed_case = []
for i in unique_countries:
  country_confirmed_case.append(data[data.Confirmed>0][data['Country/Region']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_countries, country_confirmed_case)))
# Out:
# {('Japan', 430795), ('Russia', 4187166), ('Peru', 7500), ('Hong Kong', 10983), ('Germany', 2442582), ('Italy', 2907825), ('Mainland China', 88855), ('Spain', 3188553), ('Chile', 821418), ('Denmark', 658), ('India', 11096731), ('Colombia', 2248135), ('Canada', 869154), ('Ukraine', 1389570), ('US', 0), ('Taiwan', 0), ('Mexico', 0), ('Australia', 23688), ('Brazil', 10517232), ('UK', 12177), ('France', 83122), ('Pakistan', 579973), ('Others', 0), ('Netherlands', 14854)}

# %%
unique_provinces = data['Province/State'][data.Confirmed>1].unique()
unique_provinces
# Out:
# array(['Hubei', 'Shanghai', 'Beijing', 'Henan', 'Sichuan', 'Hainan',
#        'Chongqing', 'Heilongjiang', 'Hebei', 'Tianjin', 'Guizhou',
#        'Guangdong', 'Jilin', 'Hunan', 'Gansu', 'Anhui', 'Shandong',
#        'Guangxi', 'Jiangxi', 'Liaoning', 'Hong Kong', 'Xinjiang',
#        'Taiwan', 'Yunnan', 'Zhejiang', 'Diamond Princess cruise ship',
#        'Fujian', 'Shaanxi', 'Seattle, WA', 'King County, WA',
#        'Inner Mongolia', 'New South Wales', 'British Columbia',
#        'Washington', 'California', 'France', 'UK', 'United Kingdom',
#        'Denmark', 'Netherlands', 'New Jersey', 'Kentucky', 'Ontario',
#        'Illinois', 'Western Australia', 'French Polynesia', 'Curacao',
#        'Queensland', 'Victoria', 'Guadeloupe',
#        'Australian Capital Territory', 'St Martin', 'Martinique',
#        'Mayotte', 'Tasmania', 'Sint Maarten', 'Channel Islands',
#        'Cayman Islands', 'Bermuda', 'Isle of Man', 'South Australia',
#        'Aruba', 'British Virgin Islands', 'French Guiana',
#        'Turks and Caicos Islands', 'Montserrat', 'Abruzzo', 'Alberta',
#        'Andalusia', 'Aragon', 'Asturias', 'Baden-Wurttemberg', 'Baleares',
#        'Basilicata', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
#        'C. Valenciana', 'Calabria', 'Campania', 'Canarias', 'Cantabria',
#        'Castilla - La Mancha', 'Castilla y Leon', 'Catalonia', 'Ceuta',
#        'Emilia-Romagna', 'Extremadura', 'Friuli Venezia Giulia',
#        'Galicia', 'Hamburg', 'Hessen', 'La Rioja', 'Lazio', 'Liguria',
#        'Lombardia', 'Madrid', 'Manitoba', 'Marche',
#        'Mecklenburg-Vorpommern', 'Melilla', 'Molise', 'Murcia', 'Navarra',
#        'Newfoundland and Labrador', 'Niedersachsen',
#        'Nordrhein-Westfalen', 'Nova Scotia', 'P.A. Bolzano',
#        'P.A. Trento', 'Pais Vasco', 'Piemonte', 'Puglia', 'Quebec',
#        'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt',
#        'Sardegna', 'Saskatchewan', 'Schleswig-Holstein', 'Sicilia',
#        'Thuringen', 'Toscana', 'Umbria', 'Unknown', "Valle d'Aosta",
#        'Veneto', 'Aguascalientes', 'Baja California',
#        'Baja California Sur', 'Campeche', 'Chiapas', 'Chihuahua',
#        'Ciudad de Mexico', 'Coahuila', 'Colima', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'Mexico', 'Michoacan', 'Morelos',
#        'Nayarit', 'Nuevo Leon', 'Oaxaca', 'Puebla', 'Queretaro',
#        'Quintana Roo', 'Reunion', 'San Luis Potosi', 'Sinaloa', 'Sonora',
#        'Tabasco', 'Tamaulipas', 'Tlaxcala', 'Veracruz', 'Yucatan',
#        'Zacatecas', 'Aichi', 'Amazonas', 'Antioquia', 'Aomori',
#        'Atlantico', 'Bolivar', 'Boyaca', 'Caldas', 'Capital District',
#        'Caqueta', 'Cauca', 'Cesar', 'Chiba', 'Choco', 'Cordoba',
#        'Cundinamarca', 'Ehime', 'Fukui', 'Fukuoka', 'Gifu', 'Gunma',
#        'Hiroshima', 'Hokkaido', 'Huila', 'Hyogo', 'Ibaraki', 'Ishikawa',
#        'Kanagawa', 'Kochi', 'Kumamoto', 'Kyoto', 'La Guajira',
#        'Magdalena', 'Meta', 'Mie', 'Miyagi', 'Nagasaki', 'Nara', 'Narino',
#        'Norte de Santander', 'Oita', 'Okinawa', 'Osaka', 'Quindio',
#        'Risaralda', 'Saitama', 'Santander', 'Shiga', 'Shizuoka',
#        'Tokushima', 'Tokyo', 'Tolima', 'Toyama', 'Valle del Cauca',
#        'Wakayama', 'Yamanashi', 'Putumayo', 'Adygea Republic',
#        'Altai Krai', 'Amur Oblast', 'Arkhangelsk Oblast',
#        'Astrakhan Oblast', 'Bashkortostan Republic', 'Belgorod Oblast',
#        'Bryansk Oblast', 'Buryatia Republic', 'Chechen Republic',
#        'Chelyabinsk Oblast', 'Cherkasy Oblast', 'Chernihiv Oblast',
#        'Chernivtsi Oblast', 'Chukotka Autonomous Okrug',
#        'Chuvashia Republic', 'Crimea Republic*', 'Dagestan Republic',
#        'Dnipropetrovsk Oblast', 'Donetsk Oblast', 'Ingushetia Republic',
#        'Irkutsk Oblast', 'Ivano-Frankivsk Oblast', 'Ivanovo Oblast',
#        'Jewish Autonomous Okrug', 'Kabardino-Balkarian Republic',
#        'Kaliningrad Oblast', 'Kalmykia Republic', 'Kaluga Oblast',
#        'Kamchatka Krai', 'Karachay-Cherkess Republic', 'Karelia Republic',
#        'Kemerovo Oblast', 'Khabarovsk Krai', 'Khakassia Republic',
#        'Khanty-Mansi Autonomous Okrug', 'Kharkiv Oblast',
#        'Kherson Oblast', 'Khmelnytskyi Oblast', 'Kiev', 'Kiev Oblast',
#        'Kirov Oblast', 'Kirovohrad Oblast', 'Komi Republic',
#        'Kostroma Oblast', 'Krasnodar Krai', 'Krasnoyarsk Krai',
#        'Kursk Oblast', 'Leningrad Oblast', 'Lipetsk Oblast',
#        'Lviv Oblast', 'Magadan Oblast', 'Mari El Republic',
#        'Mordovia Republic', 'Moscow', 'Moscow Oblast', 'Murmansk Oblast',
#        'Mykolaiv Oblast', 'Nizhny Novgorod Oblast',
#        'North Ossetia - Alania Republic', 'Novgorod Oblast',
#        'Novosibirsk Oblast', 'Odessa Oblast', 'Omsk Oblast',
#        'Orel Oblast', 'Orenburg Oblast', 'Penza Oblast', 'Perm Krai',
#        'Poltava Oblast', 'Primorsky Krai', 'Pskov Oblast', 'Rivne Oblast',
#        'Rostov Oblast', 'Ryazan Oblast', 'Saint Petersburg',
#        'Sakha (Yakutiya) Republic', 'Samara Oblast', 'Saratov Oblast',
#        'Sevastopol*', 'Smolensk Oblast', 'Stavropol Krai', 'Sumy Oblast',
#        'Sverdlovsk Oblast', 'Tambov Oblast', 'Tatarstan Republic',
#        'Ternopil Oblast', 'Tomsk Oblast', 'Tula Oblast', 'Tver Oblast',
#        'Tyumen Oblast', 'Tyva Republic', 'Udmurt Republic',
#        'Ulyanovsk Oblast', 'Vinnytsia Oblast', 'Vladimir Oblast',
#        'Volgograd Oblast', 'Vologda Oblast', 'Volyn Oblast',
#        'Voronezh Oblast', 'Yamalo-Nenets Autonomous Okrug',
#        'Yaroslavl Oblast', 'Zabaykalsky Krai', 'Zakarpattia Oblast',
#        'Zaporizhia Oblast', 'Zhytomyr Oblast', 'New Brunswick',
#        'Casanare', 'Sucre', 'Acre', 'Alagoas', 'Amapa', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Maranhao', 'Mato Grosso',
#        'Mato Grosso do Sul', 'Minas Gerais', 'Para', 'Paraiba', 'Parana',
#        'Pernambuco', 'Piaui', 'Rio Grande do Norte', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins', 'Michigan', 'Andhra Pradesh',
#        'Assam', 'Azad Jammu and Kashmir', 'Balochistan', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Delhi', 'Gilgit-Baltistan',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Islamabad',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Khyber Pakhtunkhwa', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Meghalaya', 'Odisha', 'Punjab', 'Rajasthan', 'Sindh',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Puducherry', 'Guainia',
#        'San Andres y Providencia', 'Goa', 'Port Quarantine',
#        'Arunachal Pradesh', 'Kurgan Oblast', 'Antofagasta', 'Araucania',
#        'Arica y Parinacota', 'Atacama', 'Biobio', 'Coquimbo', 'Los Lagos',
#        'Los Rios', 'Magallanes', 'Maule', 'Metropolitana', 'Nuble',
#        'OHiggins', 'Tarapaca', 'Valparaiso', 'Altai Republic', 'Vaupes',
#        'Yamagata', 'Goias', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Luhansk Oblast', 'Aysen', 'Arauca', 'Nagaland',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Kagoshima', 'Manipur',
#        'Tochigi', 'Miyazaki', 'Kagawa', 'Vichada', 'Guaviare', 'Okayama',
#        'Nagano', 'Yamaguchi', 'Bonaire, Sint Eustatius and Saba',
#        'Fukushima', 'Nenets Autonomous Okrug', 'Sakhalin Oblast', 'Saga',
#        'Mizoram', 'Yukon', 'Gibraltar', 'Iwate', 'Akita',
#        'Saint Barthelemy', 'Niigata', 'Nunavut', 'Faroe Islands',
#        'Tottori', 'Lakshadweep'], dtype=object)

# %%
province_confirmed_case = []
for i in unique_provinces:
  province_confirmed_case.append(data[data.Confirmed>0][data['Province/State']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_provinces, province_confirmed_case)))
# Out:
# {('Chandigarh', 21719), ('Tolima', 65123), ('Pskov Oblast', 31806), ('Rajasthan', 320180), ('Tomsk Oblast', 30218), ('Amur Oblast', 20970), ('Channel Islands', 4034), ('Amazonas', 320626), ('San Andres y Providencia', 2704), ('Andhra Pradesh', 889799), ('Penza Oblast', 38139), ('Islamabad', 44259), ('Sindh', 258004), ('Sucre', 20492), ('Assam', 217527), ('Guerrero', 0), ('Nara', 3293), ('Rondonia', 147999), ('Sint Maarten', 2055), ('Yamaguchi', 1381), ('Quintana Roo', 0), ('Antofagasta', 37536), ('Telangana', 298807), ('Hong Kong', 10983), ('Madrid', 583862), ('Chernihiv Oblast', 35829), ('Zakarpattia Oblast', 39830), ('Rio Grande do Norte', 165344), ('Castilla - La Mancha', 168561), ('Risaralda', 46008), ('Ivano-Frankivsk Oblast', 63699), ('Sicilia', 152105), ('Chiba', 26275), ('Tamaulipas', 0), ('Queretaro', 0), ('Gifu', 4613), ('Veracruz', 0), ('Khanty-Mansi Autonomous Okrug', 51352), ('Andalusia', 476822), ('C. Valenciana', 377866), ('Tula Oblast', 32920), ('Punjab', 352946), ('Campania', 265058), ('Tyumen Oblast', 31223), ('Fukushima', 1948), ('Para', 363916), ('Tamil Nadu', 851063), ('Queensland', 1329), ('Zhytomyr Oblast', 50582), ('Belgorod Oblast', 31356), ('Mari El Republic', 11754), ('Nordrhein-Westfalen', 532344), ('Goa', 54932), ('Ciudad de Mexico', 0), ('Nagasaki', 1610), ('Kalmykia Republic', 18960), ('Liguria', 77730), ('Yamanashi', 941), ('Asturias', 43179), ('Chhattisgarh', 312419), ('Kharkiv Oblast', 83539), ('Osaka', 47034), ('Rostov Oblast', 72745), ('Kaluga Oblast', 29707), ('Oita', 1291), ('Sergipe', 150533), ('Cantabria', 24574), ('Toyama', 908), ('Tarapaca', 24658), ('Alagoas', 131066), ('Fukui', 545), ('Kirovohrad Oblast', 10598), ('Bolivar', 66654), ('Rio de Janeiro', 582164), ('Kyoto', 9061), ('Chernivtsi Oblast', 54383), ('Zhejiang', 1321), ('Sachsen-Anhalt', 60630), ('Sakhalin Oblast', 21471), ('Sinaloa', 0), ('Tocantins', 113594), ('Rio Grande do Sul', 638996), ('Gunma', 4492), ('Jewish Autonomous Okrug', 4319), ('Iwate', 554), ('Kumamoto', 3441), ('Krasnoyarsk Krai', 62411), ('British Virgin Islands', 153), ('Turks and Caicos Islands', 2099), ('Newfoundland and Labrador', 981), ('La Guajira', 16131), ('Mie', 2520), ('OHiggins', 30127), ('Astrakhan Oblast', 28181), ('Himachal Pradesh', 58598), ('Kursk Oblast', 30587), ('Puducherry', 39717), ('Hiroshima', 5025), ('Odessa Oblast', 85748), ('Tianjin', 356), ('Aruba', 7876), ('Nenets Autonomous Okrug', 1023), ('Moscow', 976739), ('Sachsen', 194177), ('Nuevo Leon', 0), ('Arica y Parinacota', 15098), ('Maharashtra', 2146777), ('Sakha (Yakutiya) Republic', 32508), ('Karelia Republic', 40741), ('Mykolaiv Oblast', 42053), ('Piaui', 173290), ('Bayern', 436473), ('Kiev Oblast', 75338), ('United Kingdom', 0), ('Thuringen', 76291), ('Chuvashia Republic', 21343), ('Morelos', 0), ('California', 0), ('Gilgit-Baltistan', 4956), ('Magdalena', 33392), ('Australian Capital Territory', 118), ('Denmark', 0), ('Altai Krai', 43399), ('Arauca', 5571), ('Kanagawa', 44822), ('Miyazaki', 1947), ('Bryansk Oblast', 32795), ('Nagano', 2364), ('Metropolitana', 364151), ('France', 0), ('Tripura', 33417), ('Primorsky Krai', 40276), ('Irkutsk Oblast', 55433), ('Bashkortostan Republic', 28444), ('Moscow Oblast', 213344), ('Parana', 643344), ('Aichi', 25858), ('Choco', 6533), ('Ontario', 304962), ('Galicia', 111461), ('Hidalgo', 0), ('New Brunswick', 1430), ('Sao Paulo', 2037267), ('Novosibirsk Oblast', 35635), ('Reunion', 12416), ('Vladimir Oblast', 27295), ('Ulyanovsk Oblast', 47590), ('Rivne Oblast', 48779), ('Dadra and Nagar Haveli and Daman and Diu', 3406), ('Delhi', 639092), ('Tyva Republic', 15643), ('Campeche', 0), ('Michigan', 0), ('Valparaiso', 49881), ('Ladakh', 9818), ('Ingushetia Republic', 14719), ('Minas Gerais', 874884), ('Toscana', 155167), ('Piemonte', 246232), ('Tokushima', 449), ('Perm Krai', 46647), ('Guadeloupe', 9968), ('Extremadura', 68952), ('Tatarstan Republic', 17923), ('Donetsk Oblast', 47160), ('Calabria', 37720), ('Jharkhand', 119905), ('Cordoba', 37070 ...

# %%
nan_indices = []
for i in range(len(unique_provinces)):
  if type(unique_provinces[i])==float:
    nan_indices.append(i)

# %%
unique_provinces = list(unique_provinces)
province_confirmed_case = list(province_confirmed_case)

# %%
for i in nan_indices:
  unique_provinces.pop(i)
  province_confirmed_case.pop(i)

unique_provinces
# Out:
# ['Hubei',
#  'Shanghai',
#  'Beijing',
#  'Henan',
#  'Sichuan',
#  'Hainan',
#  'Chongqing',
#  'Heilongjiang',
#  'Hebei',
#  'Tianjin',
#  'Guizhou',
#  'Guangdong',
#  'Jilin',
#  'Hunan',
#  'Gansu',
#  'Anhui',
#  'Shandong',
#  'Guangxi',
#  'Jiangxi',
#  'Liaoning',
#  'Hong Kong',
#  'Xinjiang',
#  'Taiwan',
#  'Yunnan',
#  'Zhejiang',
#  'Diamond Princess cruise ship',
#  'Fujian',
#  'Shaanxi',
#  'Seattle, WA',
#  'King County, WA',
#  'Inner Mongolia',
#  'New South Wales',
#  'British Columbia',
#  'Washington',
#  'California',
#  'France',
#  'UK',
#  'United Kingdom',
#  'Denmark',
#  'Netherlands',
#  'New Jersey',
#  'Kentucky',
#  'Ontario',
#  'Illinois',
#  'Western Australia',
#  'French Polynesia',
#  'Curacao',
#  'Queensland',
#  'Victoria',
#  'Guadeloupe',
#  'Australian Capital Territory',
#  'St Martin',
#  'Martinique',
#  'Mayotte',
#  'Tasmania',
#  'Sint Maarten',
#  'Channel Islands',
#  'Cayman Islands',
#  'Bermuda',
#  'Isle of Man',
#  'South Australia',
#  'Aruba',
#  'British Virgin Islands',
#  'French Guiana',
#  'Turks and Caicos Islands',
#  'Montserrat',
#  'Abruzzo',
#  'Alberta',
#  'Andalusia',
#  'Aragon',
#  'Asturias',
#  'Baden-Wurttemberg',
#  'Baleares',
#  'Basilicata',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'C. Valenciana',
#  'Calabria',
#  'Campania',
#  'Canarias',
#  'Cantabria',
#  'Castilla - La Mancha',
#  'Castilla y Leon',
#  'Catalonia',
#  'Ceuta',
#  'Emilia-Romagna',
#  'Extremadura',
#  'Friuli Venezia Giulia',
#  'Galicia',
#  'Hamburg',
#  'Hessen',
#  'La Rioja',
#  'Lazio',
#  'Liguria',
#  'Lombardia',
#  'Madrid',
#  'Manitoba',
#  'Marche',
#  'Mecklenburg-Vorpommern',
#  'Melilla',
#  'Molise',
#  'Murcia',
#  'Navarra',
#  'Newfoundland and Labrador',
#  'Niedersachsen',
#  'Nordrhein-Westfalen',
#  'Nova Scotia',
#  'P.A. Bolzano',
#  'P.A. Trento',
#  'Pais Vasco',
#  'Piemonte',
#  'Puglia',
#  'Quebec',
#  'Rheinland-Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Sardegna',
#  'Saskatchewan',
#  'Schleswig-Holstein',
#  'Sicilia',
#  'Thuringen',
#  'Toscana',
#  'Umbria',
#  'Unknown',
#  "Valle d'Aosta",
#  'Veneto',
#  'Aguascalientes',
#  'Baja California',
#  'Baja California Sur',
#  'Campeche',
#  'Chiapas',
#  'Chihuahua',
#  'Ciudad de Mexico',
#  'Coahuila',
#  'Colima',
#  'Durango',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'Mexico',
#  'Michoacan',
#  'Morelos',
#  'Nayarit',
#  'Nuevo Leon',
#  'Oaxaca',
#  'Puebla',
#  'Queretaro',
#  'Quintana Roo',
#  'Reunion',
#  'San Luis Potosi',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz',
#  'Yucatan',
#  'Zacatecas',
#  'Aichi',
#  'Amazonas',
#  'Antioquia',
#  'Aomori',
#  'Atlantico',
#  'Bolivar',
#  'Boyaca',
#  'Caldas',
#  'Capital District',
#  'Caqueta',
#  'Cauca',
#  'Cesar',
#  'Chiba',
#  'Choco',
#  'Cordoba',
#  'Cundinamarca',
#  'Ehime',
#  'Fukui',
#  'Fukuoka',
#  'Gifu',
#  'Gunma',
#  'Hiroshima',
#  'Hokkaido',
#  'Huila',
#  'Hyogo',
#  'Ibaraki',
#  'Ishikawa',
#  'Kanagawa',
#  'Kochi',
#  'Kumamoto',
#  'Kyoto',
#  'La Guajira',
#  'Magdalena',
#  'Meta',
#  'Mie',
#  'Miyagi',
#  'Nagasaki',
#  'Nara',
#  'Narino',
#  'Norte de Santander',
#  'Oita',
#  'Okinawa',
#  'Osaka',
#  'Quindio',
#  'Risaralda',
#  'Saitama',
#  'Santander',
#  'Shiga',
#  'Shizuoka',
#  'Tokushima',
#  'Tokyo',
#  'Tolima',
#  'Toyama',
#  'Valle del Cauca',
#  'Wakayama',
#  'Yamanashi',
#  'Putumayo',
#  'Adygea Republic',
#  'Altai Krai',
#  'Amur Oblast',
#  'Arkhangelsk Oblast',
#  'Astrakhan Oblast',
#  'Bashkortostan Republic',
#  'Belgorod Oblast',
#  'Bryansk Oblast',
#  'Buryatia Republic',
#  'Chechen Republic',
#  'Chelyabinsk Oblast',
#  'Cherkasy Oblast',
#  'Chernihiv Oblast',
#  'Chernivtsi Oblast',
#  'Chukotka Autonomous Okrug',
#  'Chuvashia Republic',
#  'Crimea Republic*',
#  'Dagestan Republic',
#  'Dnipropetrovsk Oblast',
#  'Donetsk Oblast',
#  'Ingushetia Republic',
#  'Irkutsk Oblast',
#  'Ivano-Frankivsk Oblast',
#  'Ivanovo Oblast',
#  'Jewish Autonomous Okrug',
#  'Kabardino-Balkarian Republic',
#  'Kaliningrad Oblast',
#  'Kalmykia Republic',
#  'Kaluga Oblast',
#  'Kamchatka Krai',
#  'Karachay-Cherkess Republic',
#  'Karelia Republic',
#  'Kemerovo Oblast',
#  'Khabarovsk Krai',
#  'Khakassia Republic',
#  'Khanty-Mansi Autonomous Okrug',
#  'Kharkiv Oblast',
#  'Kherson Oblast',
#  'Khmelnytskyi Oblast',
#  'Kiev',
#  'Kiev Oblast',
#  'Kirov Oblast',
#  'Kirovohrad Oblast',
#  'Komi Republic',
#  'Kostroma Oblast',
#  'Krasnodar Krai',
#  'Krasnoyarsk Krai',
#  'Kursk Oblast',
#  'Leningrad Oblast',
#  'Lipetsk Oblast',
#  'Lviv Oblast',
#  'Magadan Oblast',
#  'Mari El Republic',
#  'Mordovia Republic',
#  'Moscow',
#  'Moscow Oblast',
#  'Murmansk Oblast',
#  'Mykolaiv Oblast',
#  'Nizhny Novgorod Oblast',
#  'North Ossetia - Alania Republic',
#  'Novgorod Oblast',
#  'Novosibirsk Oblast',
#  'Odessa Oblast',
#  'Omsk Oblast',
#  'Orel Oblast',
#  'Orenburg Oblast',
#  'Penza Oblast',
#  'Perm Krai',
#  'Poltava Oblast',
#  'Primorsky Krai',
#  'Pskov Oblast',
#  'Rivne Oblast',
#  'Rostov Oblast',
#  'Ryazan Oblast',
#  'Saint Petersburg',
#  'Sakha (Yakutiya) Republic',
#  'Samara Oblast',
#  'Saratov Oblast',
#  'Sevastopol*',
#  'Smolensk Oblast',
#  'Stavropol Krai',
#  'Sumy Oblast',
#  'Sverdlovsk Oblast',
#  'Tambov Oblast',
#  'Tatarstan Republic',
#  'Ternopil Oblast',
#  'Tomsk Oblast',
#  'Tula Oblast',
#  'Tver Oblast',
#  'Tyumen Oblast',
#  'Tyva Republic',
#  'Udmurt Republic',
#  'Ulyanovsk Oblast',
#  'Vinnytsia Oblast',
#  'Vladimir Oblast',
#  'Volgograd Oblast',
#  'Vologda Oblast',
#  'Volyn Oblast',
#  'Voronezh Oblast',
#  'Yamalo-Nenets Autonomous Okrug',
#  'Yaroslavl Oblast',
#  'Zabaykalsky Krai',
#  'Zakarpattia Oblast',
#  'Zaporizhia Oblast',
#  'Zhytomyr Oblast',
#  'New Brunswick',
#  'Casanare',
#  'Sucre',
#  'Acre',
#  'Alagoas',
#  'Amapa',
#  'Bahia',
#  'Ceara',
#  'Distrito Federal',
#  'Espirito Santo',
#  'Maranhao',
#  'Mato Grosso',
#  'Mato Grosso do Sul',
#  'Minas Gerais',
#  'Para',
#  'Paraiba',
#  'Parana',
#  'Pernambuco',
#  'Piaui',
#  'Rio Grande do Norte',
#  'Rio Grande do Sul',
#  'Rio de Janeiro',
#  'Rondonia',
#  'Roraima',
#  'Santa Catarina',
#  'Sao Paulo',
#  'Sergipe',
#  'Tocantins',
#  'Michigan',
#  'Andhra Pradesh',
#  'Assam',
#  'Azad Jammu and Kashmir',
#  'Balochistan',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Delhi',
#  'Gilgit-Baltistan',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Islamabad',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Khyber Pakhtunkhwa',
#  'Ladakh',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Meghalaya',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sindh',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'Puducherry',
#  'Guainia',
#  'San Andres y Providencia',
#  'Goa',
#  'Port Quarantine',
#  'Arunachal Pradesh',
#  'Kurgan Oblast',
#  'Antofagasta',
#  'Araucania',
#  'Arica y Parinacota',
#  'Atacama',
#  'Biobio',
#  'Coquimbo',
#  'Los Lagos',
#  'Los Rios',
#  'Magallanes',
#  'Maule',
#  'Metropolitana',
#  'Nuble',
#  'OHiggins',
#  'Tarapaca',
#  'Valparaiso',
#  'Altai Republic',
#  'Vaupes',
#  'Yamagata',
#  'Goias',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Luhansk Oblast',
#  'Aysen',
#  'Arauca',
#  'Nagaland',
#  'Andaman and Nicobar Islands',
#  'Sikkim',
#  'Kagoshima',
#  'Manipur',
#  'Tochigi',
#  'Miyazaki',
#  'Kagawa',
#  'Vichada',
#  'Guaviare',
#  'Okayama',
#  'Nagano',
#  'Yamaguchi',
#  'Bonaire, Sint Eustatius and Saba',
#  'Fukushima',
#  'Nenets Autonomous Okrug',
#  'Sakhalin Oblast',
#  'Saga',
#  'Mizoram',
#  'Yukon',
#  'Gibraltar',
#  'Iwate',
#  'Akita',
#  'Saint Barthelemy',
#  'Niigata',
#  'Nunavut',
#  'Faroe Islands',
#  'Tottori',
#  'Lakshadweep']

# %%
plt.barh(unique_countries, country_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(50,40))
plt.barh(unique_provinces, province_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(country_confirmed_case)
plt.legend(unique_countries, loc='best')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.pie(province_confirmed_case)
plt.legend(unique_provinces, loc='best')
plt.show()
